# %% [markdown]
# **Skewness test**

# %%
import pandas as pd
from scipy.stats import skew

returns = pd.read_csv(stock_df["Daily_Return"])
sk = skew(returns, bias=False)
print(f"Skewness = {sk:.3f}")

# %%
if sk > 0:
    print("Positive skew → occasional large gains")
elif sk < 0:
    print("Negative skew → occasional large losses")
else:
    print("Symmetric returns")
